# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 2
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 2:
# Samples: 10000
# Label Counts: {0: 984, 1: 1007, 2: 1010, 3: 995, 4: 1010, 5: 988, 6: 1008, 7: 1026, 8: 987, 9: 985}
# First 20 Labels: [1, 6, 6, 8, 8, 3, 4, 6, 0, 6, 0, 3, 6, 6, 5, 4, 8, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 3 Max Value: 219
# Image - Shape: (32, 32, 3)
# Label - Label Id: 3 Name: cat

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # Normalization by Scaling Between 0 and 1
    return  (x -  np.amin(x)) / (np.amax(x) - np.amin(x))


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn import preprocessing
lb = preprocessing.LabelBinarizer() 
lb.fit(range(10))
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # transform the labels into one-hot encoded vectors and return
    return lb.transform(x)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a bach of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    image_shape = (32, 32, 3)
    return tf.placeholder(tf.float32, [None, image_shape[0], \
                                       image_shape[1], image_shape[2]], 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    n_classes = 10
    return tf.placeholder(tf.float32, [None, n_classes], 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    return tf.placeholder(tf.float32, shape=None, name='keep_prob')

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """ 
    # Weight and bias
    color_channel = x_tensor.get_shape().as_list()[-1]
    weight = tf.Variable(tf.truncated_normal(
        [conv_ksize[0], conv_ksize[1], color_channel, conv_num_outputs], stddev=0.05))
    bias = tf.Variable(tf.zeros(conv_num_outputs))
    
    # Apply Convolution
    conv_layer = tf.nn.conv2d(x_tensor, 
                              weight, 
                              strides=[1, conv_strides[0], conv_strides[1], 1], 
                              padding='SAME')
    
    # Add bias
    conv_layer = tf.nn.bias_add(conv_layer, bias)
    
    # Apply nonlinear activation function
    conv_layer = tf.nn.relu(conv_layer)
    
    # Apply Max Pooling
    conv_layer = tf.nn.max_pool(conv_layer, 
                                ksize=[1, pool_ksize[0], pool_ksize[1], 1], 
                                strides=[1, pool_strides[0], pool_strides[1], 1], 
                                padding='SAME')
    
    return conv_layer 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # Ref：http://stackoverflow.com/questions/36668542/flatten-batch-in-tensorflow
    shape = x_tensor.get_shape().as_list()
    dim = np.prod(shape[1:])
    return tf.reshape(x_tensor, [-1, dim]) 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Weight and bias
    weight = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev=0.05))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    # Fully-connect layer
    fc_layer = tf.add(tf.matmul(x_tensor, weight), bias)
    
    # Apply nonlinear activation function
    fc_layer = tf.nn.relu(fc_layer)
    
    return fc_layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
        
    # Weight and bias
    weight = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev=0.05))
    bias = tf.Variable(tf.zeros(num_outputs))
    
    # Output, class prediction
    output = tf.add(tf.matmul(x_tensor, weight), bias)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    # ConvNet Architecture:
    # INPUT -> [CONV -> RELU -> POOL] * 3 -> DROPOUT -> [FC -> RELU] * 2 -> DROPOUT -> OUTPUT
    conv1 = conv2d_maxpool(x, 
                           conv_num_outputs=32, 
                           conv_ksize=(3, 3), 
                           conv_strides=(1, 1), 
                           pool_ksize=(2, 2), 
                           pool_strides=(2, 2))
    
    conv2 = conv2d_maxpool(conv1, 
                           conv_num_outputs=64, 
                           conv_ksize=(3, 3), 
                           conv_strides=(1, 1), 
                           pool_ksize=(2, 2), 
                           pool_strides=(2, 2))
    
    conv3 = conv2d_maxpool(conv2, 
                       conv_num_outputs=128, 
                       conv_ksize=(3, 3), 
                       conv_strides=(1, 1), 
                       pool_ksize=(2, 2), 
                       pool_strides=(2, 2))

    # Apply a Flatten Layer
    conv3 = flatten(conv3)
    
    # Apply dropput
    #conv3 = tf.nn.dropout(conv3, keep_prob)

    # Apply 2 Fully Connected Layers
    fc1 = fully_conn(conv3, 1024)
    # Apply dropput
    fc1 = tf.nn.dropout(fc1, keep_prob)
    fc2 = fully_conn(fc1, 128)
    

    
    # Apply an Output Layer
    out = output(fc2, 10)
    
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """

    # Keep training until reach max iterations
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    loss = session.run(cost, feed_dict={x: feature_batch,y: label_batch, keep_prob: 1.})
    acc = session.run(accuracy, feed_dict={x: valid_features,y: valid_labels, keep_prob: 1.})
    
    print("Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 256
keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Minibatch Loss= 2.137800, Training Accuracy= 0.27920
# Epoch  2, CIFAR-10 Batch 1:  Minibatch Loss= 1.910674, Training Accuracy= 0.37040
# Epoch  3, CIFAR-10 Batch 1:  Minibatch Loss= 1.771755, Training Accuracy= 0.40860
# Epoch  4, CIFAR-10 Batch 1:  Minibatch Loss= 1.617428, Training Accuracy= 0.44380
# Epoch  5, CIFAR-10 Batch 1:  Minibatch Loss= 1.441905, Training Accuracy= 0.46460
# Epoch  6, CIFAR-10 Batch 1:  Minibatch Loss= 1.222823, Training Accuracy= 0.49960
# Epoch  7, CIFAR-10 Batch 1:  Minibatch Loss= 1.046610, Training Accuracy= 0.50540
# Epoch  8, CIFAR-10 Batch 1:  Minibatch Loss= 0.917803, Training Accuracy= 0.53400
# Epoch  9, CIFAR-10 Batch 1:  Minibatch Loss= 0.777339, Training Accuracy= 0.55140
# Epoch 10, CIFAR-10 Batch 1:  Minibatch Loss= 0.656776, Training Accuracy= 0.57060
# Epoch 11, CIFAR-10 Batch 1:  Minibatch Loss= 0.526828, Training Accuracy= 0.57900
# Epoch 12, CIFAR-10 Batch 1:  Minibatch Loss= 0.395192, Training Accuracy= 0.59220
# Epoch 13, CIFAR-10 Batch 1:  Minibatch Loss= 0.319990, Training Accuracy= 0.55780
# Epoch 14, CIFAR-10 Batch 1:  Minibatch Loss= 0.288777, Training Accuracy= 0.58640
# Epoch 15, CIFAR-10 Batch 1:  Minibatch Loss= 0.224603, Training Accuracy= 0.60400
# Epoch 16, CIFAR-10 Batch 1:  Minibatch Loss= 0.159940, Training Accuracy= 0.60340
# Epoch 17, CIFAR-10 Batch 1:  Minibatch Loss= 0.146840, Training Accuracy= 0.61400
# Epoch 18, CIFAR-10 Batch 1:  Minibatch Loss= 0.148112, Training Accuracy= 0.59280
# Epoch 19, CIFAR-10 Batch 1:  Minibatch Loss= 0.091808, Training Accuracy= 0.59940
# Epoch 20, CIFAR-10 Batch 1:  Minibatch Loss= 0.052181, Training Accuracy= 0.62100
# Epoch 21, CIFAR-10 Batch 1:  Minibatch Loss= 0.068799, Training Accuracy= 0.58040
# Epoch 22, CIFAR-10 Batch 1:  Minibatch Loss= 0.038410, Training Accuracy= 0.57860
# Epoch 23, CIFAR-10 Batch 1:  Minibatch Loss= 0.034704, Training Accuracy= 0.60440
# Epoch 24, CIFAR-10 Batch 1:  Minibatch Loss= 0.031451, Training Accuracy= 0.60640
# Epoch 25, CIFAR-10 Batch 1:  Minibatch Loss= 0.018001, Training Accuracy= 0.60860
# Epoch 26, CIFAR-10 Batch 1:  Minibatch Loss= 0.016298, Training Accuracy= 0.61300
# Epoch 27, CIFAR-10 Batch 1:  Minibatch Loss= 0.013412, Training Accuracy= 0.63040
# Epoch 28, CIFAR-10 Batch 1:  Minibatch Loss= 0.009383, Training Accuracy= 0.61880
# Epoch 29, CIFAR-10 Batch 1:  Minibatch Loss= 0.007262, Training Accuracy= 0.60880
# Epoch 30, CIFAR-10 Batch 1:  Minibatch Loss= 0.021130, Training Accuracy= 0.60200
# Epoch 31, CIFAR-10 Batch 1:  Minibatch Loss= 0.021087, Training Accuracy= 0.60420
# Epoch 32, CIFAR-10 Batch 1:  Minibatch Loss= 0.006799, Training Accuracy= 0.62740
# Epoch 33, CIFAR-10 Batch 1:  Minibatch Loss= 0.015398, Training Accuracy= 0.60960
# Epoch 34, CIFAR-10 Batch 1:  Minibatch Loss= 0.036558, Training Accuracy= 0.58740
# Epoch 35, CIFAR-10 Batch 1:  Minibatch Loss= 0.007396, Training Accuracy= 0.61120
# Epoch 36, CIFAR-10 Batch 1:  Minibatch Loss= 0.001255, Training Accuracy= 0.60760
# Epoch 37, CIFAR-10 Batch 1:  Minibatch Loss= 0.001629, Training Accuracy= 0.62280
# Epoch 38, CIFAR-10 Batch 1:  Minibatch Loss= 0.000464, Training Accuracy= 0.61920
# Epoch 39, CIFAR-10 Batch 1:  Minibatch Loss= 0.000195, Training Accuracy= 0.62660
# Epoch 40, CIFAR-10 Batch 1:  Minibatch Loss= 0.000178, Training Accuracy= 0.62740
# Epoch 41, CIFAR-10 Batch 1:  Minibatch Loss= 0.000238, Training Accuracy= 0.63780
# Epoch 42, CIFAR-10 Batch 1:  Minibatch Loss= 0.000183, Training Accuracy= 0.64060
# Epoch 43, CIFAR-10 Batch 1:  Minibatch Loss= 0.000219, Training Accuracy= 0.62660
# Epoch 44, CIFAR-10 Batch 1:  Minibatch Loss= 0.000258, Training Accuracy= 0.63500
# Epoch 45, CIFAR-10 Batch 1:  Minibatch Loss= 0.000197, Training Accuracy= 0.62660
# Epoch 46, CIFAR-10 Batch 1:  Minibatch Loss= 0.000394, Training Accuracy= 0.62600
# Epoch 47, CIFAR-10 Batch 1:  Minibatch Loss= 0.000599, Training Accuracy= 0.63080
# Epoch 48, CIFAR-10 Batch 1:  Minibatch Loss= 0.000394, Training Accuracy= 0.63720
# Epoch 49, CIFAR-10 Batch 1:  Minibatch Loss= 0.000649, Training Accuracy= 0.61560
# Epoch 50, CIFAR-10 Batch 1:  Minibatch Loss= 0.000301, Training Accuracy= 0.62940
# Epoch 51, CIFAR-10 Batch 1:  Minibatch Loss= 0.000290, Training Accuracy= 0.63540
# Epoch 52, CIFAR-10 Batch 1:  Minibatch Loss= 0.000483, Training Accuracy= 0.62640
# Epoch 53, CIFAR-10 Batch 1:  Minibatch Loss= 0.000347, Training Accuracy= 0.61980
# Epoch 54, CIFAR-10 Batch 1:  Minibatch Loss= 0.000640, Training Accuracy= 0.64260
# Epoch 55, CIFAR-10 Batch 1:  Minibatch Loss= 0.001828, Training Accuracy= 0.64160
# Epoch 56, CIFAR-10 Batch 1:  Minibatch Loss= 0.000154, Training Accuracy= 0.64440
# Epoch 57, CIFAR-10 Batch 1:  Minibatch Loss= 0.000396, Training Accuracy= 0.64400
# Epoch 58, CIFAR-10 Batch 1:  Minibatch Loss= 0.001343, Training Accuracy= 0.63320
# Epoch 59, CIFAR-10 Batch 1:  Minibatch Loss= 0.000315, Training Accuracy= 0.63440
# Epoch 60, CIFAR-10 Batch 1:  Minibatch Loss= 0.000044, Training Accuracy= 0.63660
# Epoch 61, CIFAR-10 Batch 1:  Minibatch Loss= 0.000027, Training Accuracy= 0.63940
# Epoch 62, CIFAR-10 Batch 1:  Minibatch Loss= 0.000032, Training Accuracy= 0.63260
# Epoch 63, CIFAR-10 Batch 1:  Minibatch Loss= 0.000060, Training Accuracy= 0.62840
# Epoch 64, CIFAR-10 Batch 1:  Minibatch Loss= 0.000043, Training Accuracy= 0.64480
# Epoch 65, CIFAR-10 Batch 1:  Minibatch Loss= 0.000049, Training Accuracy= 0.62980
# Epoch 66, CIFAR-10 Batch 1:  Minibatch Loss= 0.000740, Training Accuracy= 0.63260
# Epoch 67, CIFAR-10 Batch 1:  Minibatch Loss= 0.000041, Training Accuracy= 0.64000
# Epoch 68, CIFAR-10 Batch 1:  Minibatch Loss= 0.000095, Training Accuracy= 0.64920
# Epoch 69, CIFAR-10 Batch 1:  Minibatch Loss= 0.000110, Training Accuracy= 0.63720
# Epoch 70, CIFAR-10 Batch 1:  Minibatch Loss= 0.000052, Training Accuracy= 0.63480
# Epoch 71, CIFAR-10 Batch 1:  Minibatch Loss= 0.000060, Training Accuracy= 0.64960
# Epoch 72, CIFAR-10 Batch 1:  Minibatch Loss= 0.000031, Training Accuracy= 0.63160
# Epoch 73, CIFAR-10 Batch 1:  Minibatch Loss= 0.000065, Training Accuracy= 0.63460
# Epoch 74, CIFAR-10 Batch 1:  Minibatch Loss= 0.000047, Training Accuracy= 0.63600
# Epoch 75, CIFAR-10 Batch 1:  Minibatch Loss= 0.000050, Training Accuracy= 0.63360
# Epoch 76, CIFAR-10 Batch 1:  Minibatch Loss= 0.000105, Training Accuracy= 0.62960
# Epoch 77, CIFAR-10 Batch 1:  Minibatch Loss= 0.000031, Training Accuracy= 0.64800
# Epoch 78, CIFAR-10 Batch 1:  Minibatch Loss= 0.000036, Training Accuracy= 0.65180
# Epoch 79, CIFAR-10 Batch 1:  Minibatch Loss= 0.000068, Training Accuracy= 0.64560
# Epoch 80, CIFAR-10 Batch 1:  Minibatch Loss= 0.000038, Training Accuracy= 0.61980
# Epoch 81, CIFAR-10 Batch 1:  Minibatch Loss= 0.000034, Training Accuracy= 0.63440
# Epoch 82, CIFAR-10 Batch 1:  Minibatch Loss= 0.000044, Training Accuracy= 0.64560
# Epoch 83, CIFAR-10 Batch 1:  Minibatch Loss= 0.004229, Training Accuracy= 0.61860
# Epoch 84, CIFAR-10 Batch 1:  Minibatch Loss= 0.000019, Training Accuracy= 0.63520
# Epoch 85, CIFAR-10 Batch 1:  Minibatch Loss= 0.000098, Training Accuracy= 0.63780
# Epoch 86, CIFAR-10 Batch 1:  Minibatch Loss= 0.000075, Training Accuracy= 0.64080
# Epoch 87, CIFAR-10 Batch 1:  Minibatch Loss= 0.000031, Training Accuracy= 0.63900
# Epoch 88, CIFAR-10 Batch 1:  Minibatch Loss= 0.000021, Training Accuracy= 0.63500
# Epoch 89, CIFAR-10 Batch 1:  Minibatch Loss= 0.000027, Training Accuracy= 0.64220
# Epoch 90, CIFAR-10 Batch 1:  Minibatch Loss= 0.000005, Training Accuracy= 0.63720
# Epoch 91, CIFAR-10 Batch 1:  Minibatch Loss= 0.000023, Training Accuracy= 0.62240
# Epoch 92, CIFAR-10 Batch 1:  Minibatch Loss= 0.000024, Training Accuracy= 0.63000
# Epoch 93, CIFAR-10 Batch 1:  Minibatch Loss= 0.000100, Training Accuracy= 0.64180
# Epoch 94, CIFAR-10 Batch 1:  Minibatch Loss= 0.000027, Training Accuracy= 0.64860
# Epoch 95, CIFAR-10 Batch 1:  Minibatch Loss= 0.000377, Training Accuracy= 0.63000
# Epoch 96, CIFAR-10 Batch 1:  Minibatch Loss= 0.000282, Training Accuracy= 0.61920
# Epoch 97, CIFAR-10 Batch 1:  Minibatch Loss= 0.000030, Training Accuracy= 0.62340
# Epoch 98, CIFAR-10 Batch 1:  Minibatch Loss= 0.000166, Training Accuracy= 0.62680
# Epoch 99, CIFAR-10 Batch 1:  Minibatch Loss= 0.000034, Training Accuracy= 0.63900
# Epoch 100, CIFAR-10 Batch 1:  Minibatch Loss= 0.000053, Training Accuracy= 0.63280

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Minibatch Loss= 2.131840, Training Accuracy= 0.29360
# Epoch  1, CIFAR-10 Batch 2:  Minibatch Loss= 1.707592, Training Accuracy= 0.36160
# Epoch  1, CIFAR-10 Batch 3:  Minibatch Loss= 1.400850, Training Accuracy= 0.41340
# Epoch  1, CIFAR-10 Batch 4:  Minibatch Loss= 1.507714, Training Accuracy= 0.42560
# Epoch  1, CIFAR-10 Batch 5:  Minibatch Loss= 1.471194, Training Accuracy= 0.46540
# Epoch  2, CIFAR-10 Batch 1:  Minibatch Loss= 1.573373, Training Accuracy= 0.48680
# Epoch  2, CIFAR-10 Batch 2:  Minibatch Loss= 1.211567, Training Accuracy= 0.48740
# Epoch  2, CIFAR-10 Batch 3:  Minibatch Loss= 1.062387, Training Accuracy= 0.52240
# Epoch  2, CIFAR-10 Batch 4:  Minibatch Loss= 1.208883, Training Accuracy= 0.54540
# Epoch  2, CIFAR-10 Batch 5:  Minibatch Loss= 1.223412, Training Accuracy= 0.54540
# Epoch  3, CIFAR-10 Batch 1:  Minibatch Loss= 1.137470, Training Accuracy= 0.57460
# Epoch  3, CIFAR-10 Batch 2:  Minibatch Loss= 0.930769, Training Accuracy= 0.60440
# Epoch  3, CIFAR-10 Batch 3:  Minibatch Loss= 0.843280, Training Accuracy= 0.58600
# Epoch  3, CIFAR-10 Batch 4:  Minibatch Loss= 0.921305, Training Accuracy= 0.58960
# Epoch  3, CIFAR-10 Batch 5:  Minibatch Loss= 0.817283, Training Accuracy= 0.63400
# Epoch  4, CIFAR-10 Batch 1:  Minibatch Loss= 0.855212, Training Accuracy= 0.62860
# Epoch  4, CIFAR-10 Batch 2:  Minibatch Loss= 0.708234, Training Accuracy= 0.63720
# Epoch  4, CIFAR-10 Batch 3:  Minibatch Loss= 0.494778, Training Accuracy= 0.64760
# Epoch  4, CIFAR-10 Batch 4:  Minibatch Loss= 0.662646, Training Accuracy= 0.65180
# Epoch  4, CIFAR-10 Batch 5:  Minibatch Loss= 0.588609, Training Accuracy= 0.66420
# Epoch  5, CIFAR-10 Batch 1:  Minibatch Loss= 0.659941, Training Accuracy= 0.66640
# Epoch  5, CIFAR-10 Batch 2:  Minibatch Loss= 0.487019, Training Accuracy= 0.67720
# Epoch  5, CIFAR-10 Batch 3:  Minibatch Loss= 0.367077, Training Accuracy= 0.67340
# Epoch  5, CIFAR-10 Batch 4:  Minibatch Loss= 0.458416, Training Accuracy= 0.66840
# Epoch  5, CIFAR-10 Batch 5:  Minibatch Loss= 0.417577, Training Accuracy= 0.67580
# Epoch  6, CIFAR-10 Batch 1:  Minibatch Loss= 0.453397, Training Accuracy= 0.69440
# Epoch  6, CIFAR-10 Batch 2:  Minibatch Loss= 0.351589, Training Accuracy= 0.67220
# Epoch  6, CIFAR-10 Batch 3:  Minibatch Loss= 0.297412, Training Accuracy= 0.67360
# Epoch  6, CIFAR-10 Batch 4:  Minibatch Loss= 0.367648, Training Accuracy= 0.69660
# Epoch  6, CIFAR-10 Batch 5:  Minibatch Loss= 0.307615, Training Accuracy= 0.68600
# Epoch  7, CIFAR-10 Batch 1:  Minibatch Loss= 0.371527, Training Accuracy= 0.70340
# Epoch  7, CIFAR-10 Batch 2:  Minibatch Loss= 0.224006, Training Accuracy= 0.67820
# Epoch  7, CIFAR-10 Batch 3:  Minibatch Loss= 0.202972, Training Accuracy= 0.72140
# Epoch  7, CIFAR-10 Batch 4:  Minibatch Loss= 0.280614, Training Accuracy= 0.71320
# Epoch  7, CIFAR-10 Batch 5:  Minibatch Loss= 0.204050, Training Accuracy= 0.73160
# Epoch  8, CIFAR-10 Batch 1:  Minibatch Loss= 0.281622, Training Accuracy= 0.70140
# Epoch  8, CIFAR-10 Batch 2:  Minibatch Loss= 0.150330, Training Accuracy= 0.70860
# Epoch  8, CIFAR-10 Batch 3:  Minibatch Loss= 0.149670, Training Accuracy= 0.74060
# Epoch  8, CIFAR-10 Batch 4:  Minibatch Loss= 0.169863, Training Accuracy= 0.73420
# Epoch  8, CIFAR-10 Batch 5:  Minibatch Loss= 0.145120, Training Accuracy= 0.73760
# Epoch  9, CIFAR-10 Batch 1:  Minibatch Loss= 0.188884, Training Accuracy= 0.71480
# Epoch  9, CIFAR-10 Batch 2:  Minibatch Loss= 0.112981, Training Accuracy= 0.70100
# Epoch  9, CIFAR-10 Batch 3:  Minibatch Loss= 0.121310, Training Accuracy= 0.73060
# Epoch  9, CIFAR-10 Batch 4:  Minibatch Loss= 0.148035, Training Accuracy= 0.73520
# Epoch  9, CIFAR-10 Batch 5:  Minibatch Loss= 0.119218, Training Accuracy= 0.71940
# Epoch 10, CIFAR-10 Batch 1:  Minibatch Loss= 0.117875, Training Accuracy= 0.72640
# Epoch 10, CIFAR-10 Batch 2:  Minibatch Loss= 0.100875, Training Accuracy= 0.73840
# Epoch 10, CIFAR-10 Batch 3:  Minibatch Loss= 0.088796, Training Accuracy= 0.74140
# Epoch 10, CIFAR-10 Batch 4:  Minibatch Loss= 0.099300, Training Accuracy= 0.75160
# Epoch 10, CIFAR-10 Batch 5:  Minibatch Loss= 0.067915, Training Accuracy= 0.73080
# Epoch 11, CIFAR-10 Batch 1:  Minibatch Loss= 0.101321, Training Accuracy= 0.73920
# Epoch 11, CIFAR-10 Batch 2:  Minibatch Loss= 0.080462, Training Accuracy= 0.74280
# Epoch 11, CIFAR-10 Batch 3:  Minibatch Loss= 0.068071, Training Accuracy= 0.73080
# Epoch 11, CIFAR-10 Batch 4:  Minibatch Loss= 0.054948, Training Accuracy= 0.75180
# Epoch 11, CIFAR-10 Batch 5:  Minibatch Loss= 0.063719, Training Accuracy= 0.72760
# Epoch 12, CIFAR-10 Batch 1:  Minibatch Loss= 0.073624, Training Accuracy= 0.73940
# Epoch 12, CIFAR-10 Batch 2:  Minibatch Loss= 0.055274, Training Accuracy= 0.74740
# Epoch 12, CIFAR-10 Batch 3:  Minibatch Loss= 0.060794, Training Accuracy= 0.72740
# Epoch 12, CIFAR-10 Batch 4:  Minibatch Loss= 0.048461, Training Accuracy= 0.74640
# Epoch 12, CIFAR-10 Batch 5:  Minibatch Loss= 0.035897, Training Accuracy= 0.73940
# Epoch 13, CIFAR-10 Batch 1:  Minibatch Loss= 0.065270, Training Accuracy= 0.73060
# Epoch 13, CIFAR-10 Batch 2:  Minibatch Loss= 0.043503, Training Accuracy= 0.74140
# Epoch 13, CIFAR-10 Batch 3:  Minibatch Loss= 0.039116, Training Accuracy= 0.74720
# Epoch 13, CIFAR-10 Batch 4:  Minibatch Loss= 0.032578, Training Accuracy= 0.75280
# Epoch 13, CIFAR-10 Batch 5:  Minibatch Loss= 0.022736, Training Accuracy= 0.74180
# Epoch 14, CIFAR-10 Batch 1:  Minibatch Loss= 0.029890, Training Accuracy= 0.75480
# Epoch 14, CIFAR-10 Batch 2:  Minibatch Loss= 0.036289, Training Accuracy= 0.74260
# Epoch 14, CIFAR-10 Batch 3:  Minibatch Loss= 0.025842, Training Accuracy= 0.75880
# Epoch 14, CIFAR-10 Batch 4:  Minibatch Loss= 0.028385, Training Accuracy= 0.74020
# Epoch 14, CIFAR-10 Batch 5:  Minibatch Loss= 0.017022, Training Accuracy= 0.76100
# Epoch 15, CIFAR-10 Batch 1:  Minibatch Loss= 0.021804, Training Accuracy= 0.75040
# Epoch 15, CIFAR-10 Batch 2:  Minibatch Loss= 0.019125, Training Accuracy= 0.74980
# Epoch 15, CIFAR-10 Batch 3:  Minibatch Loss= 0.020269, Training Accuracy= 0.75760
# Epoch 15, CIFAR-10 Batch 4:  Minibatch Loss= 0.020851, Training Accuracy= 0.73940
# Epoch 15, CIFAR-10 Batch 5:  Minibatch Loss= 0.021935, Training Accuracy= 0.76380
# Epoch 16, CIFAR-10 Batch 1:  Minibatch Loss= 0.026130, Training Accuracy= 0.73340
# Epoch 16, CIFAR-10 Batch 2:  Minibatch Loss= 0.011484, Training Accuracy= 0.73780
# Epoch 16, CIFAR-10 Batch 3:  Minibatch Loss= 0.012167, Training Accuracy= 0.74800
# Epoch 16, CIFAR-10 Batch 4:  Minibatch Loss= 0.024473, Training Accuracy= 0.73440
# Epoch 16, CIFAR-10 Batch 5:  Minibatch Loss= 0.009235, Training Accuracy= 0.76480
# Epoch 17, CIFAR-10 Batch 1:  Minibatch Loss= 0.011563, Training Accuracy= 0.75700
# Epoch 17, CIFAR-10 Batch 2:  Minibatch Loss= 0.007107, Training Accuracy= 0.74820
# Epoch 17, CIFAR-10 Batch 3:  Minibatch Loss= 0.005135, Training Accuracy= 0.76000
# Epoch 17, CIFAR-10 Batch 4:  Minibatch Loss= 0.026848, Training Accuracy= 0.74780
# Epoch 17, CIFAR-10 Batch 5:  Minibatch Loss= 0.011424, Training Accuracy= 0.74780
# Epoch 18, CIFAR-10 Batch 1:  Minibatch Loss= 0.010454, Training Accuracy= 0.75160
# Epoch 18, CIFAR-10 Batch 2:  Minibatch Loss= 0.012929, Training Accuracy= 0.72740
# Epoch 18, CIFAR-10 Batch 3:  Minibatch Loss= 0.005928, Training Accuracy= 0.75840
# Epoch 18, CIFAR-10 Batch 4:  Minibatch Loss= 0.007495, Training Accuracy= 0.75080
# Epoch 18, CIFAR-10 Batch 5:  Minibatch Loss= 0.007916, Training Accuracy= 0.75180
# Epoch 19, CIFAR-10 Batch 1:  Minibatch Loss= 0.005440, Training Accuracy= 0.76280
# Epoch 19, CIFAR-10 Batch 2:  Minibatch Loss= 0.004715, Training Accuracy= 0.73620
# Epoch 19, CIFAR-10 Batch 3:  Minibatch Loss= 0.008433, Training Accuracy= 0.75900
# Epoch 19, CIFAR-10 Batch 4:  Minibatch Loss= 0.008531, Training Accuracy= 0.74220
# Epoch 19, CIFAR-10 Batch 5:  Minibatch Loss= 0.004955, Training Accuracy= 0.74980
# Epoch 20, CIFAR-10 Batch 1:  Minibatch Loss= 0.004748, Training Accuracy= 0.76360
# Epoch 20, CIFAR-10 Batch 2:  Minibatch Loss= 0.003150, Training Accuracy= 0.73580
# Epoch 20, CIFAR-10 Batch 3:  Minibatch Loss= 0.005388, Training Accuracy= 0.75860
# Epoch 20, CIFAR-10 Batch 4:  Minibatch Loss= 0.008820, Training Accuracy= 0.76080
# Epoch 20, CIFAR-10 Batch 5:  Minibatch Loss= 0.004298, Training Accuracy= 0.74620
# Epoch 21, CIFAR-10 Batch 1:  Minibatch Loss= 0.004256, Training Accuracy= 0.76380
# Epoch 21, CIFAR-10 Batch 2:  Minibatch Loss= 0.002883, Training Accuracy= 0.74660
# Epoch 21, CIFAR-10 Batch 3:  Minibatch Loss= 0.005041, Training Accuracy= 0.74140
# Epoch 21, CIFAR-10 Batch 4:  Minibatch Loss= 0.002214, Training Accuracy= 0.75660
# Epoch 21, CIFAR-10 Batch 5:  Minibatch Loss= 0.002268, Training Accuracy= 0.75440
# Epoch 22, CIFAR-10 Batch 1:  Minibatch Loss= 0.002042, Training Accuracy= 0.76740
# Epoch 22, CIFAR-10 Batch 2:  Minibatch Loss= 0.001253, Training Accuracy= 0.75560
# Epoch 22, CIFAR-10 Batch 3:  Minibatch Loss= 0.003747, Training Accuracy= 0.76260
# Epoch 22, CIFAR-10 Batch 4:  Minibatch Loss= 0.002708, Training Accuracy= 0.75060
# Epoch 22, CIFAR-10 Batch 5:  Minibatch Loss= 0.003708, Training Accuracy= 0.75360
# Epoch 23, CIFAR-10 Batch 1:  Minibatch Loss= 0.001812, Training Accuracy= 0.75840
# Epoch 23, CIFAR-10 Batch 2:  Minibatch Loss= 0.012196, Training Accuracy= 0.76320
# Epoch 23, CIFAR-10 Batch 3:  Minibatch Loss= 0.002330, Training Accuracy= 0.76300
# Epoch 23, CIFAR-10 Batch 4:  Minibatch Loss= 0.002762, Training Accuracy= 0.74040
# Epoch 23, CIFAR-10 Batch 5:  Minibatch Loss= 0.002344, Training Accuracy= 0.75280
# Epoch 24, CIFAR-10 Batch 1:  Minibatch Loss= 0.003864, Training Accuracy= 0.72760
# Epoch 24, CIFAR-10 Batch 2:  Minibatch Loss= 0.000693, Training Accuracy= 0.76280
# Epoch 24, CIFAR-10 Batch 3:  Minibatch Loss= 0.001193, Training Accuracy= 0.75340
# Epoch 24, CIFAR-10 Batch 4:  Minibatch Loss= 0.003659, Training Accuracy= 0.75040
# Epoch 24, CIFAR-10 Batch 5:  Minibatch Loss= 0.001578, Training Accuracy= 0.76740
# Epoch 25, CIFAR-10 Batch 1:  Minibatch Loss= 0.002394, Training Accuracy= 0.71860
# Epoch 25, CIFAR-10 Batch 2:  Minibatch Loss= 0.001030, Training Accuracy= 0.76060
# Epoch 25, CIFAR-10 Batch 3:  Minibatch Loss= 0.002234, Training Accuracy= 0.74500
# Epoch 25, CIFAR-10 Batch 4:  Minibatch Loss= 0.003420, Training Accuracy= 0.73560
# Epoch 25, CIFAR-10 Batch 5:  Minibatch Loss= 0.001213, Training Accuracy= 0.75320
# Epoch 26, CIFAR-10 Batch 1:  Minibatch Loss= 0.000539, Training Accuracy= 0.74940
# Epoch 26, CIFAR-10 Batch 2:  Minibatch Loss= 0.000549, Training Accuracy= 0.76860
# Epoch 26, CIFAR-10 Batch 3:  Minibatch Loss= 0.003175, Training Accuracy= 0.75460
# Epoch 26, CIFAR-10 Batch 4:  Minibatch Loss= 0.001752, Training Accuracy= 0.75860
# Epoch 26, CIFAR-10 Batch 5:  Minibatch Loss= 0.000950, Training Accuracy= 0.75120
# Epoch 27, CIFAR-10 Batch 1:  Minibatch Loss= 0.000671, Training Accuracy= 0.72960
# Epoch 27, CIFAR-10 Batch 2:  Minibatch Loss= 0.000714, Training Accuracy= 0.76560
# Epoch 27, CIFAR-10 Batch 3:  Minibatch Loss= 0.001922, Training Accuracy= 0.75180
# Epoch 27, CIFAR-10 Batch 4:  Minibatch Loss= 0.000906, Training Accuracy= 0.75460
# Epoch 27, CIFAR-10 Batch 5:  Minibatch Loss= 0.001396, Training Accuracy= 0.75340
# Epoch 28, CIFAR-10 Batch 1:  Minibatch Loss= 0.000500, Training Accuracy= 0.75820
# Epoch 28, CIFAR-10 Batch 2:  Minibatch Loss= 0.000534, Training Accuracy= 0.76560
# Epoch 28, CIFAR-10 Batch 3:  Minibatch Loss= 0.002675, Training Accuracy= 0.74960
# Epoch 28, CIFAR-10 Batch 4:  Minibatch Loss= 0.002095, Training Accuracy= 0.76760
# Epoch 28, CIFAR-10 Batch 5:  Minibatch Loss= 0.001070, Training Accuracy= 0.75440
# Epoch 29, CIFAR-10 Batch 1:  Minibatch Loss= 0.000963, Training Accuracy= 0.73860
# Epoch 29, CIFAR-10 Batch 2:  Minibatch Loss= 0.000237, Training Accuracy= 0.75740
# Epoch 29, CIFAR-10 Batch 3:  Minibatch Loss= 0.000189, Training Accuracy= 0.74980
# Epoch 29, CIFAR-10 Batch 4:  Minibatch Loss= 0.000751, Training Accuracy= 0.75280
# Epoch 29, CIFAR-10 Batch 5:  Minibatch Loss= 0.003384, Training Accuracy= 0.75840
# Epoch 30, CIFAR-10 Batch 1:  Minibatch Loss= 0.004925, Training Accuracy= 0.75120
# Epoch 30, CIFAR-10 Batch 2:  Minibatch Loss= 0.000304, Training Accuracy= 0.76900
# Epoch 30, CIFAR-10 Batch 3:  Minibatch Loss= 0.000521, Training Accuracy= 0.76140
# Epoch 30, CIFAR-10 Batch 4:  Minibatch Loss= 0.001840, Training Accuracy= 0.75680
# Epoch 30, CIFAR-10 Batch 5:  Minibatch Loss= 0.001178, Training Accuracy= 0.76760
# Epoch 31, CIFAR-10 Batch 1:  Minibatch Loss= 0.000972, Training Accuracy= 0.77200
# Epoch 31, CIFAR-10 Batch 2:  Minibatch Loss= 0.000570, Training Accuracy= 0.75480
# Epoch 31, CIFAR-10 Batch 3:  Minibatch Loss= 0.003511, Training Accuracy= 0.74660
# Epoch 31, CIFAR-10 Batch 4:  Minibatch Loss= 0.000841, Training Accuracy= 0.75460
# Epoch 31, CIFAR-10 Batch 5:  Minibatch Loss= 0.000465, Training Accuracy= 0.76340
# Epoch 32, CIFAR-10 Batch 1:  Minibatch Loss= 0.001490, Training Accuracy= 0.76000
# Epoch 32, CIFAR-10 Batch 2:  Minibatch Loss= 0.000786, Training Accuracy= 0.75420
# Epoch 32, CIFAR-10 Batch 3:  Minibatch Loss= 0.000364, Training Accuracy= 0.75820
# Epoch 32, CIFAR-10 Batch 4:  Minibatch Loss= 0.000445, Training Accuracy= 0.76860
# Epoch 32, CIFAR-10 Batch 5:  Minibatch Loss= 0.001031, Training Accuracy= 0.76340
# Epoch 33, CIFAR-10 Batch 1:  Minibatch Loss= 0.000471, Training Accuracy= 0.75500
# Epoch 33, CIFAR-10 Batch 2:  Minibatch Loss= 0.000344, Training Accuracy= 0.76480
# Epoch 33, CIFAR-10 Batch 3:  Minibatch Loss= 0.000318, Training Accuracy= 0.74620
# Epoch 33, CIFAR-10 Batch 4:  Minibatch Loss= 0.004653, Training Accuracy= 0.74740
# Epoch 33, CIFAR-10 Batch 5:  Minibatch Loss= 0.000451, Training Accuracy= 0.75960
# Epoch 34, CIFAR-10 Batch 1:  Minibatch Loss= 0.000248, Training Accuracy= 0.76920
# Epoch 34, CIFAR-10 Batch 2:  Minibatch Loss= 0.001273, Training Accuracy= 0.75600
# Epoch 34, CIFAR-10 Batch 3:  Minibatch Loss= 0.000797, Training Accuracy= 0.75560
# Epoch 34, CIFAR-10 Batch 4:  Minibatch Loss= 0.001996, Training Accuracy= 0.75000
# Epoch 34, CIFAR-10 Batch 5:  Minibatch Loss= 0.000387, Training Accuracy= 0.76760
# Epoch 35, CIFAR-10 Batch 1:  Minibatch Loss= 0.000236, Training Accuracy= 0.76100
# Epoch 35, CIFAR-10 Batch 2:  Minibatch Loss= 0.000171, Training Accuracy= 0.76040
# Epoch 35, CIFAR-10 Batch 3:  Minibatch Loss= 0.000111, Training Accuracy= 0.74780
# Epoch 35, CIFAR-10 Batch 4:  Minibatch Loss= 0.000611, Training Accuracy= 0.75780
# Epoch 35, CIFAR-10 Batch 5:  Minibatch Loss= 0.000075, Training Accuracy= 0.75980
# Epoch 36, CIFAR-10 Batch 1:  Minibatch Loss= 0.000099, Training Accuracy= 0.76920
# Epoch 36, CIFAR-10 Batch 2:  Minibatch Loss= 0.000150, Training Accuracy= 0.76640
# Epoch 36, CIFAR-10 Batch 3:  Minibatch Loss= 0.000397, Training Accuracy= 0.75200
# Epoch 36, CIFAR-10 Batch 4:  Minibatch Loss= 0.000219, Training Accuracy= 0.75700
# Epoch 36, CIFAR-10 Batch 5:  Minibatch Loss= 0.000597, Training Accuracy= 0.76780
# Epoch 37, CIFAR-10 Batch 1:  Minibatch Loss= 0.000132, Training Accuracy= 0.76980
# Epoch 37, CIFAR-10 Batch 2:  Minibatch Loss= 0.000115, Training Accuracy= 0.75220
# Epoch 37, CIFAR-10 Batch 3:  Minibatch Loss= 0.000200, Training Accuracy= 0.75560
# Epoch 37, CIFAR-10 Batch 4:  Minibatch Loss= 0.000435, Training Accuracy= 0.76240
# Epoch 37, CIFAR-10 Batch 5:  Minibatch Loss= 0.000053, Training Accuracy= 0.77240
# Epoch 38, CIFAR-10 Batch 1:  Minibatch Loss= 0.000048, Training Accuracy= 0.76480
# Epoch 38, CIFAR-10 Batch 2:  Minibatch Loss= 0.000076, Training Accuracy= 0.75940
# Epoch 38, CIFAR-10 Batch 3:  Minibatch Loss= 0.000040, Training Accuracy= 0.76700
# Epoch 38, CIFAR-10 Batch 4:  Minibatch Loss= 0.000167, Training Accuracy= 0.75440
# Epoch 38, CIFAR-10 Batch 5:  Minibatch Loss= 0.000151, Training Accuracy= 0.76580
# Epoch 39, CIFAR-10 Batch 1:  Minibatch Loss= 0.000061, Training Accuracy= 0.76500
# Epoch 39, CIFAR-10 Batch 2:  Minibatch Loss= 0.000137, Training Accuracy= 0.77120
# Epoch 39, CIFAR-10 Batch 3:  Minibatch Loss= 0.000127, Training Accuracy= 0.75920
# Epoch 39, CIFAR-10 Batch 4:  Minibatch Loss= 0.000131, Training Accuracy= 0.75620
# Epoch 39, CIFAR-10 Batch 5:  Minibatch Loss= 0.000853, Training Accuracy= 0.77460
# Epoch 40, CIFAR-10 Batch 1:  Minibatch Loss= 0.000083, Training Accuracy= 0.76560
# Epoch 40, CIFAR-10 Batch 2:  Minibatch Loss= 0.000342, Training Accuracy= 0.75580
# Epoch 40, CIFAR-10 Batch 3:  Minibatch Loss= 0.000140, Training Accuracy= 0.75660
# Epoch 40, CIFAR-10 Batch 4:  Minibatch Loss= 0.000422, Training Accuracy= 0.76360
# Epoch 40, CIFAR-10 Batch 5:  Minibatch Loss= 0.000052, Training Accuracy= 0.76440
# Epoch 41, CIFAR-10 Batch 1:  Minibatch Loss= 0.000210, Training Accuracy= 0.77400
# Epoch 41, CIFAR-10 Batch 2:  Minibatch Loss= 0.000039, Training Accuracy= 0.76600
# Epoch 41, CIFAR-10 Batch 3:  Minibatch Loss= 0.000649, Training Accuracy= 0.76500
# Epoch 41, CIFAR-10 Batch 4:  Minibatch Loss= 0.000468, Training Accuracy= 0.77000
# Epoch 41, CIFAR-10 Batch 5:  Minibatch Loss= 0.000075, Training Accuracy= 0.77640
# Epoch 42, CIFAR-10 Batch 1:  Minibatch Loss= 0.000166, Training Accuracy= 0.76920
# Epoch 42, CIFAR-10 Batch 2:  Minibatch Loss= 0.000063, Training Accuracy= 0.77220
# Epoch 42, CIFAR-10 Batch 3:  Minibatch Loss= 0.000087, Training Accuracy= 0.77520
# Epoch 42, CIFAR-10 Batch 4:  Minibatch Loss= 0.000441, Training Accuracy= 0.75540
# Epoch 42, CIFAR-10 Batch 5:  Minibatch Loss= 0.000197, Training Accuracy= 0.75520
# Epoch 43, CIFAR-10 Batch 1:  Minibatch Loss= 0.000155, Training Accuracy= 0.77540
# Epoch 43, CIFAR-10 Batch 2:  Minibatch Loss= 0.000081, Training Accuracy= 0.76520
# Epoch 43, CIFAR-10 Batch 3:  Minibatch Loss= 0.000295, Training Accuracy= 0.76640
# Epoch 43, CIFAR-10 Batch 4:  Minibatch Loss= 0.001431, Training Accuracy= 0.76580
# Epoch 43, CIFAR-10 Batch 5:  Minibatch Loss= 0.000106, Training Accuracy= 0.77000
# Epoch 44, CIFAR-10 Batch 1:  Minibatch Loss= 0.000102, Training Accuracy= 0.77520
# Epoch 44, CIFAR-10 Batch 2:  Minibatch Loss= 0.000113, Training Accuracy= 0.76240
# Epoch 44, CIFAR-10 Batch 3:  Minibatch Loss= 0.000095, Training Accuracy= 0.76700
# Epoch 44, CIFAR-10 Batch 4:  Minibatch Loss= 0.001009, Training Accuracy= 0.76160
# Epoch 44, CIFAR-10 Batch 5:  Minibatch Loss= 0.000088, Training Accuracy= 0.76760
# Epoch 45, CIFAR-10 Batch 1:  Minibatch Loss= 0.000046, Training Accuracy= 0.76740
# Epoch 45, CIFAR-10 Batch 2:  Minibatch Loss= 0.000053, Training Accuracy= 0.76420
# Epoch 45, CIFAR-10 Batch 3:  Minibatch Loss= 0.000020, Training Accuracy= 0.76460
# Epoch 45, CIFAR-10 Batch 4:  Minibatch Loss= 0.000265, Training Accuracy= 0.76440
# Epoch 45, CIFAR-10 Batch 5:  Minibatch Loss= 0.000133, Training Accuracy= 0.76220
# Epoch 46, CIFAR-10 Batch 1:  Minibatch Loss= 0.000032, Training Accuracy= 0.77080
# Epoch 46, CIFAR-10 Batch 2:  Minibatch Loss= 0.000085, Training Accuracy= 0.76920
# Epoch 46, CIFAR-10 Batch 3:  Minibatch Loss= 0.000371, Training Accuracy= 0.76520
# Epoch 46, CIFAR-10 Batch 4:  Minibatch Loss= 0.000219, Training Accuracy= 0.77100
# Epoch 46, CIFAR-10 Batch 5:  Minibatch Loss= 0.000919, Training Accuracy= 0.75620
# Epoch 47, CIFAR-10 Batch 1:  Minibatch Loss= 0.000037, Training Accuracy= 0.77820
# Epoch 47, CIFAR-10 Batch 2:  Minibatch Loss= 0.000038, Training Accuracy= 0.77840
# Epoch 47, CIFAR-10 Batch 3:  Minibatch Loss= 0.000018, Training Accuracy= 0.76680
# Epoch 47, CIFAR-10 Batch 4:  Minibatch Loss= 0.000353, Training Accuracy= 0.76020
# Epoch 47, CIFAR-10 Batch 5:  Minibatch Loss= 0.000173, Training Accuracy= 0.76880
# Epoch 48, CIFAR-10 Batch 1:  Minibatch Loss= 0.000026, Training Accuracy= 0.76560
# Epoch 48, CIFAR-10 Batch 2:  Minibatch Loss= 0.000052, Training Accuracy= 0.76920
# Epoch 48, CIFAR-10 Batch 3:  Minibatch Loss= 0.000169, Training Accuracy= 0.76700
# Epoch 48, CIFAR-10 Batch 4:  Minibatch Loss= 0.001277, Training Accuracy= 0.76800
# Epoch 48, CIFAR-10 Batch 5:  Minibatch Loss= 0.000383, Training Accuracy= 0.76080
# Epoch 49, CIFAR-10 Batch 1:  Minibatch Loss= 0.000024, Training Accuracy= 0.77240
# Epoch 49, CIFAR-10 Batch 2:  Minibatch Loss= 0.000855, Training Accuracy= 0.77200
# Epoch 49, CIFAR-10 Batch 3:  Minibatch Loss= 0.000155, Training Accuracy= 0.76580
# Epoch 49, CIFAR-10 Batch 4:  Minibatch Loss= 0.000117, Training Accuracy= 0.76920
# Epoch 49, CIFAR-10 Batch 5:  Minibatch Loss= 0.000081, Training Accuracy= 0.76760
# Epoch 50, CIFAR-10 Batch 1:  Minibatch Loss= 0.000052, Training Accuracy= 0.76180
# Epoch 50, CIFAR-10 Batch 2:  Minibatch Loss= 0.000115, Training Accuracy= 0.75560
# Epoch 50, CIFAR-10 Batch 3:  Minibatch Loss= 0.000016, Training Accuracy= 0.76900
# Epoch 50, CIFAR-10 Batch 4:  Minibatch Loss= 0.000145, Training Accuracy= 0.76160
# Epoch 50, CIFAR-10 Batch 5:  Minibatch Loss= 0.000479, Training Accuracy= 0.76380
# Epoch 51, CIFAR-10 Batch 1:  Minibatch Loss= 0.000156, Training Accuracy= 0.75960
# Epoch 51, CIFAR-10 Batch 2:  Minibatch Loss= 0.000030, Training Accuracy= 0.76100
# Epoch 51, CIFAR-10 Batch 3:  Minibatch Loss= 0.000130, Training Accuracy= 0.77040
# Epoch 51, CIFAR-10 Batch 4:  Minibatch Loss= 0.014231, Training Accuracy= 0.77120
# Epoch 51, CIFAR-10 Batch 5:  Minibatch Loss= 0.000344, Training Accuracy= 0.76700
# Epoch 52, CIFAR-10 Batch 1:  Minibatch Loss= 0.000376, Training Accuracy= 0.74900
# Epoch 52, CIFAR-10 Batch 2:  Minibatch Loss= 0.000066, Training Accuracy= 0.77220
# Epoch 52, CIFAR-10 Batch 3:  Minibatch Loss= 0.000073, Training Accuracy= 0.75820
# Epoch 52, CIFAR-10 Batch 4:  Minibatch Loss= 0.002303, Training Accuracy= 0.76060
# Epoch 52, CIFAR-10 Batch 5:  Minibatch Loss= 0.000124, Training Accuracy= 0.77020
# Epoch 53, CIFAR-10 Batch 1:  Minibatch Loss= 0.000038, Training Accuracy= 0.75700
# Epoch 53, CIFAR-10 Batch 2:  Minibatch Loss= 0.000051, Training Accuracy= 0.77240
# Epoch 53, CIFAR-10 Batch 3:  Minibatch Loss= 0.002261, Training Accuracy= 0.76240
# Epoch 53, CIFAR-10 Batch 4:  Minibatch Loss= 0.000419, Training Accuracy= 0.77580
# Epoch 53, CIFAR-10 Batch 5:  Minibatch Loss= 0.000021, Training Accuracy= 0.76220
# Epoch 54, CIFAR-10 Batch 1:  Minibatch Loss= 0.000026, Training Accuracy= 0.74920
# Epoch 54, CIFAR-10 Batch 2:  Minibatch Loss= 0.001039, Training Accuracy= 0.76720
# Epoch 54, CIFAR-10 Batch 3:  Minibatch Loss= 0.000137, Training Accuracy= 0.76880
# Epoch 54, CIFAR-10 Batch 4:  Minibatch Loss= 0.001288, Training Accuracy= 0.74740
# Epoch 54, CIFAR-10 Batch 5:  Minibatch Loss= 0.000577, Training Accuracy= 0.76260
# Epoch 55, CIFAR-10 Batch 1:  Minibatch Loss= 0.000064, Training Accuracy= 0.76160
# Epoch 55, CIFAR-10 Batch 2:  Minibatch Loss= 0.000021, Training Accuracy= 0.76460
# Epoch 55, CIFAR-10 Batch 3:  Minibatch Loss= 0.000033, Training Accuracy= 0.77240
# Epoch 55, CIFAR-10 Batch 4:  Minibatch Loss= 0.000293, Training Accuracy= 0.76980
# Epoch 55, CIFAR-10 Batch 5:  Minibatch Loss= 0.000041, Training Accuracy= 0.77120
# Epoch 56, CIFAR-10 Batch 1:  Minibatch Loss= 0.000172, Training Accuracy= 0.75880
# Epoch 56, CIFAR-10 Batch 2:  Minibatch Loss= 0.000119, Training Accuracy= 0.76760
# Epoch 56, CIFAR-10 Batch 3:  Minibatch Loss= 0.000059, Training Accuracy= 0.76280
# Epoch 56, CIFAR-10 Batch 4:  Minibatch Loss= 0.000180, Training Accuracy= 0.77280
# Epoch 56, CIFAR-10 Batch 5:  Minibatch Loss= 0.000094, Training Accuracy= 0.75820
# Epoch 57, CIFAR-10 Batch 1:  Minibatch Loss= 0.000126, Training Accuracy= 0.75140
# Epoch 57, CIFAR-10 Batch 2:  Minibatch Loss= 0.000123, Training Accuracy= 0.77000
# Epoch 57, CIFAR-10 Batch 3:  Minibatch Loss= 0.000013, Training Accuracy= 0.76440
# Epoch 57, CIFAR-10 Batch 4:  Minibatch Loss= 0.000008, Training Accuracy= 0.77460
# Epoch 57, CIFAR-10 Batch 5:  Minibatch Loss= 0.000087, Training Accuracy= 0.77020
# Epoch 58, CIFAR-10 Batch 1:  Minibatch Loss= 0.000392, Training Accuracy= 0.75720
# Epoch 58, CIFAR-10 Batch 2:  Minibatch Loss= 0.000009, Training Accuracy= 0.76860
# Epoch 58, CIFAR-10 Batch 3:  Minibatch Loss= 0.000022, Training Accuracy= 0.77220
# Epoch 58, CIFAR-10 Batch 4:  Minibatch Loss= 0.000034, Training Accuracy= 0.76560
# Epoch 58, CIFAR-10 Batch 5:  Minibatch Loss= 0.000442, Training Accuracy= 0.76380
# Epoch 59, CIFAR-10 Batch 1:  Minibatch Loss= 0.000044, Training Accuracy= 0.74680
# Epoch 59, CIFAR-10 Batch 2:  Minibatch Loss= 0.000018, Training Accuracy= 0.76860
# Epoch 59, CIFAR-10 Batch 3:  Minibatch Loss= 0.000029, Training Accuracy= 0.76400
# Epoch 59, CIFAR-10 Batch 4:  Minibatch Loss= 0.000013, Training Accuracy= 0.76260
# Epoch 59, CIFAR-10 Batch 5:  Minibatch Loss= 0.000096, Training Accuracy= 0.76080
# Epoch 60, CIFAR-10 Batch 1:  Minibatch Loss= 0.000008, Training Accuracy= 0.76520
# Epoch 60, CIFAR-10 Batch 2:  Minibatch Loss= 0.000224, Training Accuracy= 0.77460
# Epoch 60, CIFAR-10 Batch 3:  Minibatch Loss= 0.000021, Training Accuracy= 0.76460
# Epoch 60, CIFAR-10 Batch 4:  Minibatch Loss= 0.000040, Training Accuracy= 0.76280
# Epoch 60, CIFAR-10 Batch 5:  Minibatch Loss= 0.000006, Training Accuracy= 0.76800
# Epoch 61, CIFAR-10 Batch 1:  Minibatch Loss= 0.000268, Training Accuracy= 0.76140
# Epoch 61, CIFAR-10 Batch 2:  Minibatch Loss= 0.000010, Training Accuracy= 0.76740
# Epoch 61, CIFAR-10 Batch 3:  Minibatch Loss= 0.000104, Training Accuracy= 0.76540
# Epoch 61, CIFAR-10 Batch 4:  Minibatch Loss= 0.000032, Training Accuracy= 0.76260
# Epoch 61, CIFAR-10 Batch 5:  Minibatch Loss= 0.000015, Training Accuracy= 0.76660
# Epoch 62, CIFAR-10 Batch 1:  Minibatch Loss= 0.000055, Training Accuracy= 0.76780
# Epoch 62, CIFAR-10 Batch 2:  Minibatch Loss= 0.000199, Training Accuracy= 0.77340
# Epoch 62, CIFAR-10 Batch 3:  Minibatch Loss= 0.000071, Training Accuracy= 0.76340
# Epoch 62, CIFAR-10 Batch 4:  Minibatch Loss= 0.000119, Training Accuracy= 0.77180
# Epoch 62, CIFAR-10 Batch 5:  Minibatch Loss= 0.000018, Training Accuracy= 0.76920
# Epoch 63, CIFAR-10 Batch 1:  Minibatch Loss= 0.000007, Training Accuracy= 0.76580
# Epoch 63, CIFAR-10 Batch 2:  Minibatch Loss= 0.000019, Training Accuracy= 0.77660
# Epoch 63, CIFAR-10 Batch 3:  Minibatch Loss= 0.000019, Training Accuracy= 0.77620
# Epoch 63, CIFAR-10 Batch 4:  Minibatch Loss= 0.000043, Training Accuracy= 0.77360
# Epoch 63, CIFAR-10 Batch 5:  Minibatch Loss= 0.000005, Training Accuracy= 0.76280
# Epoch 64, CIFAR-10 Batch 1:  Minibatch Loss= 0.000005, Training Accuracy= 0.76520
# Epoch 64, CIFAR-10 Batch 2:  Minibatch Loss= 0.000008, Training Accuracy= 0.77260
# Epoch 64, CIFAR-10 Batch 3:  Minibatch Loss= 0.000178, Training Accuracy= 0.76900
# Epoch 64, CIFAR-10 Batch 4:  Minibatch Loss= 0.000040, Training Accuracy= 0.76580
# Epoch 64, CIFAR-10 Batch 5:  Minibatch Loss= 0.000026, Training Accuracy= 0.76320
# Epoch 65, CIFAR-10 Batch 1:  Minibatch Loss= 0.000033, Training Accuracy= 0.75920
# Epoch 65, CIFAR-10 Batch 2:  Minibatch Loss= 0.000094, Training Accuracy= 0.77020
# Epoch 65, CIFAR-10 Batch 3:  Minibatch Loss= 0.000067, Training Accuracy= 0.77080
# Epoch 65, CIFAR-10 Batch 4:  Minibatch Loss= 0.000009, Training Accuracy= 0.77400
# Epoch 65, CIFAR-10 Batch 5:  Minibatch Loss= 0.000156, Training Accuracy= 0.77060
# Epoch 66, CIFAR-10 Batch 1:  Minibatch Loss= 0.000024, Training Accuracy= 0.77280
# Epoch 66, CIFAR-10 Batch 2:  Minibatch Loss= 0.000184, Training Accuracy= 0.77420
# Epoch 66, CIFAR-10 Batch 3:  Minibatch Loss= 0.000063, Training Accuracy= 0.77400
# Epoch 66, CIFAR-10 Batch 4:  Minibatch Loss= 0.000023, Training Accuracy= 0.77480
# Epoch 66, CIFAR-10 Batch 5:  Minibatch Loss= 0.000165, Training Accuracy= 0.77360
# Epoch 67, CIFAR-10 Batch 1:  Minibatch Loss= 0.000157, Training Accuracy= 0.77280
# Epoch 67, CIFAR-10 Batch 2:  Minibatch Loss= 0.000069, Training Accuracy= 0.78140
# Epoch 67, CIFAR-10 Batch 3:  Minibatch Loss= 0.000042, Training Accuracy= 0.77900
# Epoch 67, CIFAR-10 Batch 4:  Minibatch Loss= 0.000026, Training Accuracy= 0.76640
# Epoch 67, CIFAR-10 Batch 5:  Minibatch Loss= 0.000064, Training Accuracy= 0.76180
# Epoch 68, CIFAR-10 Batch 1:  Minibatch Loss= 0.000008, Training Accuracy= 0.76640
# Epoch 68, CIFAR-10 Batch 2:  Minibatch Loss= 0.000061, Training Accuracy= 0.76840
# Epoch 68, CIFAR-10 Batch 3:  Minibatch Loss= 0.000160, Training Accuracy= 0.76800
# Epoch 68, CIFAR-10 Batch 4:  Minibatch Loss= 0.000015, Training Accuracy= 0.76660
# Epoch 68, CIFAR-10 Batch 5:  Minibatch Loss= 0.000102, Training Accuracy= 0.76960
# Epoch 69, CIFAR-10 Batch 1:  Minibatch Loss= 0.000021, Training Accuracy= 0.76420
# Epoch 69, CIFAR-10 Batch 2:  Minibatch Loss= 0.000017, Training Accuracy= 0.77160
# Epoch 69, CIFAR-10 Batch 3:  Minibatch Loss= 0.000022, Training Accuracy= 0.77360
# Epoch 69, CIFAR-10 Batch 4:  Minibatch Loss= 0.000048, Training Accuracy= 0.77600
# Epoch 69, CIFAR-10 Batch 5:  Minibatch Loss= 0.000145, Training Accuracy= 0.77760
# Epoch 70, CIFAR-10 Batch 1:  Minibatch Loss= 0.000104, Training Accuracy= 0.77420
# Epoch 70, CIFAR-10 Batch 2:  Minibatch Loss= 0.000009, Training Accuracy= 0.78440
# Epoch 70, CIFAR-10 Batch 3:  Minibatch Loss= 0.000173, Training Accuracy= 0.76860
# Epoch 70, CIFAR-10 Batch 4:  Minibatch Loss= 0.000083, Training Accuracy= 0.76740
# Epoch 70, CIFAR-10 Batch 5:  Minibatch Loss= 0.000044, Training Accuracy= 0.77580
# Epoch 71, CIFAR-10 Batch 1:  Minibatch Loss= 0.000291, Training Accuracy= 0.77300
# Epoch 71, CIFAR-10 Batch 2:  Minibatch Loss= 0.000027, Training Accuracy= 0.78240
# Epoch 71, CIFAR-10 Batch 3:  Minibatch Loss= 0.000259, Training Accuracy= 0.77500
# Epoch 71, CIFAR-10 Batch 4:  Minibatch Loss= 0.000111, Training Accuracy= 0.76560
# Epoch 71, CIFAR-10 Batch 5:  Minibatch Loss= 0.000059, Training Accuracy= 0.77860
# Epoch 72, CIFAR-10 Batch 1:  Minibatch Loss= 0.000003, Training Accuracy= 0.77560
# Epoch 72, CIFAR-10 Batch 2:  Minibatch Loss= 0.000007, Training Accuracy= 0.77820
# Epoch 72, CIFAR-10 Batch 3:  Minibatch Loss= 0.000026, Training Accuracy= 0.77200
# Epoch 72, CIFAR-10 Batch 4:  Minibatch Loss= 0.000030, Training Accuracy= 0.77060
# Epoch 72, CIFAR-10 Batch 5:  Minibatch Loss= 0.000013, Training Accuracy= 0.77200
# Epoch 73, CIFAR-10 Batch 1:  Minibatch Loss= 0.000013, Training Accuracy= 0.76600
# Epoch 73, CIFAR-10 Batch 2:  Minibatch Loss= 0.000291, Training Accuracy= 0.77160
# Epoch 73, CIFAR-10 Batch 3:  Minibatch Loss= 0.000464, Training Accuracy= 0.76660
# Epoch 73, CIFAR-10 Batch 4:  Minibatch Loss= 0.000027, Training Accuracy= 0.76440
# Epoch 73, CIFAR-10 Batch 5:  Minibatch Loss= 0.000056, Training Accuracy= 0.77520
# Epoch 74, CIFAR-10 Batch 1:  Minibatch Loss= 0.000010, Training Accuracy= 0.77300
# Epoch 74, CIFAR-10 Batch 2:  Minibatch Loss= 0.000119, Training Accuracy= 0.77340
# Epoch 74, CIFAR-10 Batch 3:  Minibatch Loss= 0.000022, Training Accuracy= 0.77400
# Epoch 74, CIFAR-10 Batch 4:  Minibatch Loss= 0.000016, Training Accuracy= 0.77160
# Epoch 74, CIFAR-10 Batch 5:  Minibatch Loss= 0.000007, Training Accuracy= 0.77380
# Epoch 75, CIFAR-10 Batch 1:  Minibatch Loss= 0.000012, Training Accuracy= 0.77580
# Epoch 75, CIFAR-10 Batch 2:  Minibatch Loss= 0.000066, Training Accuracy= 0.77280
# Epoch 75, CIFAR-10 Batch 3:  Minibatch Loss= 0.000055, Training Accuracy= 0.77360
# Epoch 75, CIFAR-10 Batch 4:  Minibatch Loss= 0.000071, Training Accuracy= 0.77120
# Epoch 75, CIFAR-10 Batch 5:  Minibatch Loss= 0.000006, Training Accuracy= 0.76500
# Epoch 76, CIFAR-10 Batch 1:  Minibatch Loss= 0.000005, Training Accuracy= 0.77480
# Epoch 76, CIFAR-10 Batch 2:  Minibatch Loss= 0.000027, Training Accuracy= 0.77140
# Epoch 76, CIFAR-10 Batch 3:  Minibatch Loss= 0.000136, Training Accuracy= 0.77340
# Epoch 76, CIFAR-10 Batch 4:  Minibatch Loss= 0.000426, Training Accuracy= 0.75840
# Epoch 76, CIFAR-10 Batch 5:  Minibatch Loss= 0.000004, Training Accuracy= 0.77620
# Epoch 77, CIFAR-10 Batch 1:  Minibatch Loss= 0.000047, Training Accuracy= 0.77200
# Epoch 77, CIFAR-10 Batch 2:  Minibatch Loss= 0.000019, Training Accuracy= 0.76900
# Epoch 77, CIFAR-10 Batch 3:  Minibatch Loss= 0.000944, Training Accuracy= 0.76320
# Epoch 77, CIFAR-10 Batch 4:  Minibatch Loss= 0.000142, Training Accuracy= 0.76460
# Epoch 77, CIFAR-10 Batch 5:  Minibatch Loss= 0.000151, Training Accuracy= 0.77220
# Epoch 78, CIFAR-10 Batch 1:  Minibatch Loss= 0.000005, Training Accuracy= 0.77260
# Epoch 78, CIFAR-10 Batch 2:  Minibatch Loss= 0.000001, Training Accuracy= 0.77540
# Epoch 78, CIFAR-10 Batch 3:  Minibatch Loss= 0.000015, Training Accuracy= 0.77360
# Epoch 78, CIFAR-10 Batch 4:  Minibatch Loss= 0.000014, Training Accuracy= 0.76940
# Epoch 78, CIFAR-10 Batch 5:  Minibatch Loss= 0.000046, Training Accuracy= 0.77860
# Epoch 79, CIFAR-10 Batch 1:  Minibatch Loss= 0.000001, Training Accuracy= 0.77580
# Epoch 79, CIFAR-10 Batch 2:  Minibatch Loss= 0.000025, Training Accuracy= 0.76600
# Epoch 79, CIFAR-10 Batch 3:  Minibatch Loss= 0.000221, Training Accuracy= 0.76640
# Epoch 79, CIFAR-10 Batch 4:  Minibatch Loss= 0.000096, Training Accuracy= 0.75980
# Epoch 79, CIFAR-10 Batch 5:  Minibatch Loss= 0.000008, Training Accuracy= 0.77360
# Epoch 80, CIFAR-10 Batch 1:  Minibatch Loss= 0.000014, Training Accuracy= 0.76580
# Epoch 80, CIFAR-10 Batch 2:  Minibatch Loss= 0.000033, Training Accuracy= 0.76880
# Epoch 80, CIFAR-10 Batch 3:  Minibatch Loss= 0.003569, Training Accuracy= 0.77160
# Epoch 80, CIFAR-10 Batch 4:  Minibatch Loss= 0.000017, Training Accuracy= 0.76820
# Epoch 80, CIFAR-10 Batch 5:  Minibatch Loss= 0.004514, Training Accuracy= 0.77460
# Epoch 81, CIFAR-10 Batch 1:  Minibatch Loss= 0.000004, Training Accuracy= 0.77300
# Epoch 81, CIFAR-10 Batch 2:  Minibatch Loss= 0.000078, Training Accuracy= 0.77960
# Epoch 81, CIFAR-10 Batch 3:  Minibatch Loss= 0.000237, Training Accuracy= 0.78400
# Epoch 81, CIFAR-10 Batch 4:  Minibatch Loss= 0.000055, Training Accuracy= 0.78200
# Epoch 81, CIFAR-10 Batch 5:  Minibatch Loss= 0.000005, Training Accuracy= 0.77940
# Epoch 82, CIFAR-10 Batch 1:  Minibatch Loss= 0.000062, Training Accuracy= 0.77220
# Epoch 82, CIFAR-10 Batch 2:  Minibatch Loss= 0.000063, Training Accuracy= 0.76980
# Epoch 82, CIFAR-10 Batch 3:  Minibatch Loss= 0.000202, Training Accuracy= 0.77080
# Epoch 82, CIFAR-10 Batch 4:  Minibatch Loss= 0.000646, Training Accuracy= 0.76360
# Epoch 82, CIFAR-10 Batch 5:  Minibatch Loss= 0.000009, Training Accuracy= 0.77300
# Epoch 83, CIFAR-10 Batch 1:  Minibatch Loss= 0.000006, Training Accuracy= 0.77800
# Epoch 83, CIFAR-10 Batch 2:  Minibatch Loss= 0.000113, Training Accuracy= 0.78000
# Epoch 83, CIFAR-10 Batch 3:  Minibatch Loss= 0.000147, Training Accuracy= 0.76440
# Epoch 83, CIFAR-10 Batch 4:  Minibatch Loss= 0.000064, Training Accuracy= 0.76740
# Epoch 83, CIFAR-10 Batch 5:  Minibatch Loss= 0.000043, Training Accuracy= 0.77680
# Epoch 84, CIFAR-10 Batch 1:  Minibatch Loss= 0.000004, Training Accuracy= 0.78020
# Epoch 84, CIFAR-10 Batch 2:  Minibatch Loss= 0.000126, Training Accuracy= 0.77640
# Epoch 84, CIFAR-10 Batch 3:  Minibatch Loss= 0.000279, Training Accuracy= 0.77920
# Epoch 84, CIFAR-10 Batch 4:  Minibatch Loss= 0.000070, Training Accuracy= 0.75960
# Epoch 84, CIFAR-10 Batch 5:  Minibatch Loss= 0.000016, Training Accuracy= 0.77640
# Epoch 85, CIFAR-10 Batch 1:  Minibatch Loss= 0.000014, Training Accuracy= 0.77560
# Epoch 85, CIFAR-10 Batch 2:  Minibatch Loss= 0.000028, Training Accuracy= 0.77700
# Epoch 85, CIFAR-10 Batch 3:  Minibatch Loss= 0.000094, Training Accuracy= 0.76680
# Epoch 85, CIFAR-10 Batch 4:  Minibatch Loss= 0.000041, Training Accuracy= 0.76980
# Epoch 85, CIFAR-10 Batch 5:  Minibatch Loss= 0.000016, Training Accuracy= 0.77720
# Epoch 86, CIFAR-10 Batch 1:  Minibatch Loss= 0.000076, Training Accuracy= 0.76440
# Epoch 86, CIFAR-10 Batch 2:  Minibatch Loss= 0.000010, Training Accuracy= 0.77860
# Epoch 86, CIFAR-10 Batch 3:  Minibatch Loss= 0.000069, Training Accuracy= 0.76540
# Epoch 86, CIFAR-10 Batch 4:  Minibatch Loss= 0.000079, Training Accuracy= 0.77560
# Epoch 86, CIFAR-10 Batch 5:  Minibatch Loss= 0.000019, Training Accuracy= 0.78020
# Epoch 87, CIFAR-10 Batch 1:  Minibatch Loss= 0.000018, Training Accuracy= 0.77640
# Epoch 87, CIFAR-10 Batch 2:  Minibatch Loss= 0.000007, Training Accuracy= 0.77000
# Epoch 87, CIFAR-10 Batch 3:  Minibatch Loss= 0.000175, Training Accuracy= 0.76380
# Epoch 87, CIFAR-10 Batch 4:  Minibatch Loss= 0.000110, Training Accuracy= 0.77500
# Epoch 87, CIFAR-10 Batch 5:  Minibatch Loss= 0.000073, Training Accuracy= 0.77900
# Epoch 88, CIFAR-10 Batch 1:  Minibatch Loss= 0.000010, Training Accuracy= 0.77320
# Epoch 88, CIFAR-10 Batch 2:  Minibatch Loss= 0.000003, Training Accuracy= 0.77600
# Epoch 88, CIFAR-10 Batch 3:  Minibatch Loss= 0.000053, Training Accuracy= 0.76080
# Epoch 88, CIFAR-10 Batch 4:  Minibatch Loss= 0.000009, Training Accuracy= 0.77640
# Epoch 88, CIFAR-10 Batch 5:  Minibatch Loss= 0.000062, Training Accuracy= 0.77680
# Epoch 89, CIFAR-10 Batch 1:  Minibatch Loss= 0.000009, Training Accuracy= 0.78400
# Epoch 89, CIFAR-10 Batch 2:  Minibatch Loss= 0.000008, Training Accuracy= 0.76940
# Epoch 89, CIFAR-10 Batch 3:  Minibatch Loss= 0.000012, Training Accuracy= 0.76300
# Epoch 89, CIFAR-10 Batch 4:  Minibatch Loss= 0.000081, Training Accuracy= 0.76380
# Epoch 89, CIFAR-10 Batch 5:  Minibatch Loss= 0.000029, Training Accuracy= 0.76580
# Epoch 90, CIFAR-10 Batch 1:  Minibatch Loss= 0.000011, Training Accuracy= 0.77140
# Epoch 90, CIFAR-10 Batch 2:  Minibatch Loss= 0.000025, Training Accuracy= 0.77060
# Epoch 90, CIFAR-10 Batch 3:  Minibatch Loss= 0.000011, Training Accuracy= 0.77000
# Epoch 90, CIFAR-10 Batch 4:  Minibatch Loss= 0.000028, Training Accuracy= 0.77200
# Epoch 90, CIFAR-10 Batch 5:  Minibatch Loss= 0.000052, Training Accuracy= 0.76960
# Epoch 91, CIFAR-10 Batch 1:  Minibatch Loss= 0.000007, Training Accuracy= 0.76820
# Epoch 91, CIFAR-10 Batch 2:  Minibatch Loss= 0.000005, Training Accuracy= 0.77160
# Epoch 91, CIFAR-10 Batch 3:  Minibatch Loss= 0.000017, Training Accuracy= 0.75980
# Epoch 91, CIFAR-10 Batch 4:  Minibatch Loss= 0.000031, Training Accuracy= 0.76800
# Epoch 91, CIFAR-10 Batch 5:  Minibatch Loss= 0.000011, Training Accuracy= 0.76960
# Epoch 92, CIFAR-10 Batch 1:  Minibatch Loss= 0.000014, Training Accuracy= 0.76680
# Epoch 92, CIFAR-10 Batch 2:  Minibatch Loss= 0.000047, Training Accuracy= 0.77060
# Epoch 92, CIFAR-10 Batch 3:  Minibatch Loss= 0.000006, Training Accuracy= 0.76400
# Epoch 92, CIFAR-10 Batch 4:  Minibatch Loss= 0.000078, Training Accuracy= 0.77400
# Epoch 92, CIFAR-10 Batch 5:  Minibatch Loss= 0.000526, Training Accuracy= 0.77440
# Epoch 93, CIFAR-10 Batch 1:  Minibatch Loss= 0.000010, Training Accuracy= 0.77340
# Epoch 93, CIFAR-10 Batch 2:  Minibatch Loss= 0.000001, Training Accuracy= 0.77280
# Epoch 93, CIFAR-10 Batch 3:  Minibatch Loss= 0.000031, Training Accuracy= 0.75800
# Epoch 93, CIFAR-10 Batch 4:  Minibatch Loss= 0.000010, Training Accuracy= 0.77240
# Epoch 93, CIFAR-10 Batch 5:  Minibatch Loss= 0.000029, Training Accuracy= 0.77540
# Epoch 94, CIFAR-10 Batch 1:  Minibatch Loss= 0.000241, Training Accuracy= 0.77560
# Epoch 94, CIFAR-10 Batch 2:  Minibatch Loss= 0.000006, Training Accuracy= 0.77240
# Epoch 94, CIFAR-10 Batch 3:  Minibatch Loss= 0.000008, Training Accuracy= 0.77680
# Epoch 94, CIFAR-10 Batch 4:  Minibatch Loss= 0.000075, Training Accuracy= 0.76860
# Epoch 94, CIFAR-10 Batch 5:  Minibatch Loss= 0.000003, Training Accuracy= 0.77980
# Epoch 95, CIFAR-10 Batch 1:  Minibatch Loss= 0.000053, Training Accuracy= 0.77620
# Epoch 95, CIFAR-10 Batch 2:  Minibatch Loss= 0.000003, Training Accuracy= 0.77980
# Epoch 95, CIFAR-10 Batch 3:  Minibatch Loss= 0.000003, Training Accuracy= 0.76060
# Epoch 95, CIFAR-10 Batch 4:  Minibatch Loss= 0.000008, Training Accuracy= 0.77300
# Epoch 95, CIFAR-10 Batch 5:  Minibatch Loss= 0.000005, Training Accuracy= 0.76700
# Epoch 96, CIFAR-10 Batch 1:  Minibatch Loss= 0.000033, Training Accuracy= 0.76860
# Epoch 96, CIFAR-10 Batch 2:  Minibatch Loss= 0.000001, Training Accuracy= 0.77180
# Epoch 96, CIFAR-10 Batch 3:  Minibatch Loss= 0.000065, Training Accuracy= 0.77560
# Epoch 96, CIFAR-10 Batch 4:  Minibatch Loss= 0.000206, Training Accuracy= 0.77100
# Epoch 96, CIFAR-10 Batch 5:  Minibatch Loss= 0.000007, Training Accuracy= 0.76940
# Epoch 97, CIFAR-10 Batch 1:  Minibatch Loss= 0.000004, Training Accuracy= 0.77380
# Epoch 97, CIFAR-10 Batch 2:  Minibatch Loss= 0.000006, Training Accuracy= 0.76780
# Epoch 97, CIFAR-10 Batch 3:  Minibatch Loss= 0.000012, Training Accuracy= 0.77380
# Epoch 97, CIFAR-10 Batch 4:  Minibatch Loss= 0.000019, Training Accuracy= 0.77880
# Epoch 97, CIFAR-10 Batch 5:  Minibatch Loss= 0.000002, Training Accuracy= 0.77720
# Epoch 98, CIFAR-10 Batch 1:  Minibatch Loss= 0.000007, Training Accuracy= 0.77740
# Epoch 98, CIFAR-10 Batch 2:  Minibatch Loss= 0.000018, Training Accuracy= 0.76740
# Epoch 98, CIFAR-10 Batch 3:  Minibatch Loss= 0.000011, Training Accuracy= 0.77720
# Epoch 98, CIFAR-10 Batch 4:  Minibatch Loss= 0.000048, Training Accuracy= 0.77180
# Epoch 98, CIFAR-10 Batch 5:  Minibatch Loss= 0.000013, Training Accuracy= 0.76360
# Epoch 99, CIFAR-10 Batch 1:  Minibatch Loss= 0.000024, Training Accuracy= 0.77260
# Epoch 99, CIFAR-10 Batch 2:  Minibatch Loss= 0.000028, Training Accuracy= 0.76480
# Epoch 99, CIFAR-10 Batch 3:  Minibatch Loss= 0.000013, Training Accuracy= 0.76940
# Epoch 99, CIFAR-10 Batch 4:  Minibatch Loss= 0.000162, Training Accuracy= 0.76620
# Epoch 99, CIFAR-10 Batch 5:  Minibatch Loss= 0.000022, Training Accuracy= 0.77540
# Epoch 100, CIFAR-10 Batch 1:  Minibatch Loss= 0.000003, Training Accuracy= 0.77580
# Epoch 100, CIFAR-10 Batch 2:  Minibatch Loss= 0.000008, Training Accuracy= 0.77120
# Epoch 100, CIFAR-10 Batch 3:  Minibatch Loss= 0.000040, Training Accuracy= 0.77580
# Epoch 100, CIFAR-10 Batch 4:  Minibatch Loss= 0.000006, Training Accuracy= 0.76980
# Epoch 100, CIFAR-10 Batch 5:  Minibatch Loss= 0.000011, Training Accuracy= 0.77300

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7626953125

# %% [markdown]
# ## Why 50-70% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 70%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
